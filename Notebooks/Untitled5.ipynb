# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT DISTINCT ?business ?official_name WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
  # ?business wdt:P31 wd:Q4830453.
  OPTIONAL { ?business wdt:P1448 ?official_name. }
  OPTIONAL { ?business wdt:P452 ?industry. }
}
LIMIT 100"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


results = get_results(endpoint_url, query)

for result in results["results"]["bindings"]:
    print(result)
# Out:
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q74716'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Grass Valley K.K'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q74716'}, 'official_name': {'xml:lang': 'ja', 'type': 'literal', 'value': 'グラスバレー株式会社'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43386'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43487'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43709'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q44027'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26921'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26924'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26944'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26952'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q26989'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27065'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27091'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27152'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27143'}, 'official_name': {'xml:lang': 'cs', 'type': 'literal', 'value': 'AVIA Motors s.r.o.'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8093'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nintendo Co., Ltd.'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8093'}, 'official_name': {'xml:lang': 'ja', 'type': 'literal', 'value': '任天堂株式会社'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q380'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q386'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q483'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1343'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1346'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1422'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1902'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3122'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3310'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3615'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3895'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4294'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4585'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4990'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4995'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6742'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6750'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6751'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6795'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7240'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7527'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8061'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8322'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q8405'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q95'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Google'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q364'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'GitHub'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2283'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Microsoft Corporation'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1418'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nokia Corporation'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1418'}, 'official_name': {'xml:lang': 'fi', 'type': 'literal', 'value': 'Nokia Oyj'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3312'}, 'official_name': {'xml:lang': 'el', 'type': 'literal', 'value': 'ΤΡΑΠΕΖΑ ΠΕΙΡΑΙΩΣ ΑΝΩΝΥΜΟΣ ΕΤΑΙΡΕΙΑ'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3312'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'PIRAEUS BANK SA'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1418'}, 'official_name': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Nokia Abp'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4548'}, 'official_name': {'xml:lang': 'tr', 'type': 'literal', 'value': 'Türk Hava Yolları Anonim Ortaklığı'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7414'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Disney Brothers Cartoon Studio'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7414'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Walt Disney Productions'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7414'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Walt Disney Studio'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q248'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Intel Corporation'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q312'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Apple Inc.'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2311'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Airbus SE'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q7414'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Walt Disney Company'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q67'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Airbus SE'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q66'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'THE BOEING COMPANY'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3884'}, 'official_name': {'xml:lang': 'en', 'type': 'literal', 'value': 'AMAZON.COM, INC.'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27158'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27224'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27300'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27325'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27334'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27377'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27392'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27401'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27415'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27423'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27432'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27460'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27474'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27483'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27511'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27530'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27539'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27550'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27582'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27586'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27585'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27597'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27717'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27760'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27786'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27879'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27893'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28255'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28529'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28616'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28993'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29041'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29281'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29755'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29803'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29855'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29852'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29913'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30113'}}
# {'business': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30346'}}
